# %% [markdown]
# # 100 meters world record
#
# <img src="Images/100m.jpg" width="800"/>

# %% [markdown]
# [Men's 100 metres world record progression](https://en.wikipedia.org/wiki/Men's_100_metres_world_record_progression#Records_since_1977)
# in wikipedia is written to file 'times_100m.dat'.

# %%
# %cat 'times_100m.dat'
# Out:
# Time  | Wind | Auto  | Athlete        | Nationality   | Location of race      | Date
# 10.06 | 1.3  |       | Bob Hayes      | United States | Tokyo, Japan          | October 15, 1964
# 10.03 | 0.8  |       | Jim Hines      | United States | Sacramento, USA       | June 20, 1968
# 10.02 | 2.0  |       | Charles Greene | United States | Mexico City, Mexico   | October 13, 1968
#  9.95 | 0.3  |       | Jim Hines      | United States | Mexico City, Mexico   | October 14, 1968
#  9.93 | 1.4  |       | Calvin Smith   | United States | Colorado Springs, USA | July 3, 1983
#  9.83 | 1.0  |       | Ben Johnson    | Canada        | Rome, Italy           | August 30, 1987
#  9.93 | 1.1  |       | Carl Lewis     | United States | Rome, Italy           | August 30, 1987
#  9.93 | 1.1  |       | Carl Lewis     | United States | Zürich, Switzerland   | August 17, 1988
#  9.79 | 1.1  |       | Ben Johnson    | Canada        | Seoul, South Korea    | September 24, 1988
#  9.92 | 1.1  |       | Carl Lewis     | United States | Seoul, South Korea    | September 24, 1988
#  9.90 | 1.9  |       | Leroy Burrell  | United States | New York, USA         | June 14, 1991
#  9.86 | 1.2  |       | Carl Lewis     | United States | Tokyo, Japan          | August 25, 1991
#  9.85 | 1.2  |       | Leroy Burrell  | United States | Lausanne, Switzerland | July 6, 1994
#  9.84 | 0.7  | 9.835 | Donovan Bailey | Canada        | Atlanta, USA          | July 27, 1996
#  9.79 | 0.1  |       | Maurice Greene | United States | Athens, Greece        | June 16, 1999
#  9.78 | 2.0  |       | Tim Montgomery | United States | Paris, France         | September 14, 2002
#  9.77 | 1.6  | 9.768 | Asafa Powell   | Jamaica       | Athens, Greece        | June 14, 2005
#  9.77 | 1.7  | 9.766 | Justin Gatlin  | United States | Doha, Qatar           | May 12, 2006
#  9.77 | 1.5  | 9.763 | Asafa Powell   | Jamaica       | Gateshead, England    | June 11, 2006
#  9.77 | 1.0  | 9.762 | Asafa Powell   | Jamaica       | Zürich, Switzerland   | August 18, 2006
#  9.74 | 1.7  | 9.735 | Asafa Powell   | Jamaica       | Rieti, Italy          | September 9, 2007
#  9.72 | 1.7  |       | Usain Bolt     | Jamaica       | New York, USA         | May 31, 2008
#  9.69 | 0.0  | 9.683 | Usain Bolt     | Jamaica       | Beijing, China        | August 16, 2008
#  9.58 | 0.9  | 9.572 | Usain Bolt     | Jamaica       | Berlin, Germany       | August 16, 2009

# %% [markdown]
# ### Men's 100 meters world record example
# 1. **read** file data
# 1. store data in a data container
#    * store data as **list** (one element for line) of **lists** (one element for column, every line is stored as a list)
# 1. manage data to get **informations** about men's 100 meters world record

# %% [markdown]
# world record informations are loaded in data.

# %%
file_data = "times_100m.dat"        # file with data

with open(file_data, 'r') as f:     # open file in read mode
    keys = f.readline()             # read first line for keys
    data = []                       # empty list for data
    for line in f:                  # loop over file lines
        record = []                 # inialize one record with empty list
        for i in line.split("|"):   # loop over columns (split line with | separator)
            column = i.strip()      # strip column to remove blank space       
            record.append(column)   # append column to record list
        data.append(record)         # append record to data list

# %%
with open(file_data, 'r') as f:
    keys = f.readline()
    data = [ [ i.strip() for i in line.split("|") ] for line in f ]

# %% [markdown]
# dataset is a list

# %%
type(data)
# Out:
# list

# %% [markdown]
# every world record data is a list

# %%
type(data[0])
# Out:
# list

# %%
data[-1]
# Out:
# ['9.58',
#  '0.9',
#  '9.572',
#  'Usain Bolt',
#  'Jamaica',
#  'Berlin, Germany',
#  'August 16, 2009']

# %%
for i in data: # loop over all world record
    print(i[0], " - ", i[3]) # print Time (1st column) and Athletes (4th column)
# Out:
# 10.06  -  Bob Hayes
# 10.03  -  Jim Hines
# 10.02  -  Charles Greene
# 9.95  -  Jim Hines
# 9.93  -  Calvin Smith
# 9.83  -  Ben Johnson
# 9.93  -  Carl Lewis
# 9.93  -  Carl Lewis
# 9.79  -  Ben Johnson
# 9.92  -  Carl Lewis
# 9.90  -  Leroy Burrell
# 9.86  -  Carl Lewis
# 9.85  -  Leroy Burrell
# 9.84  -  Donovan Bailey
# 9.79  -  Maurice Greene
# 9.78  -  Tim Montgomery
# 9.77  -  Asafa Powell
# 9.77  -  Justin Gatlin
# 9.77  -  Asafa Powell
# 9.77  -  Asafa Powell
# 9.74  -  Asafa Powell
# 9.72  -  Usain Bolt
# 9.69  -  Usain Bolt
# 9.58  -  Usain Bolt

# %% [markdown]
# ### How can we know column indices of the table?

# %% [markdown]
# The keys of the table are read by first line of file data

# %%
keys = [i.strip() for i in keys.split("|")]

keys
# Out:
# ['Time', 'Wind', 'Auto', 'Athlete', 'Nationality', 'Location of race', 'Date']

# %% [markdown]
# We can get column index for a given key using `index` method of `list`

# %%
keys.index('Date')
# Out:
# 6

# %% [markdown]
# Therefore we can access data also without explicit know column index

# %%
for i in data:
    print(i[keys.index('Time')], " - ", i[keys.index('Athlete')])
# Out:
# 10.06  -  Bob Hayes
# 10.03  -  Jim Hines
# 10.02  -  Charles Greene
# 9.95  -  Jim Hines
# 9.93  -  Calvin Smith
# 9.83  -  Ben Johnson
# 9.93  -  Carl Lewis
# 9.93  -  Carl Lewis
# 9.79  -  Ben Johnson
# 9.92  -  Carl Lewis
# 9.90  -  Leroy Burrell
# 9.86  -  Carl Lewis
# 9.85  -  Leroy Burrell
# 9.84  -  Donovan Bailey
# 9.79  -  Maurice Greene
# 9.78  -  Tim Montgomery
# 9.77  -  Asafa Powell
# 9.77  -  Justin Gatlin
# 9.77  -  Asafa Powell
# 9.77  -  Asafa Powell
# 9.74  -  Asafa Powell
# 9.72  -  Usain Bolt
# 9.69  -  Usain Bolt
# 9.58  -  Usain Bolt

# %% [markdown]
# The solution of using a **list of lists** for storing data is **not optimal**
# * column index should be known
# * otherwise accessing data by key is not straightforward
# * and not efficient (the `index` method is called every time)

# %% [markdown]
# # dictionary
#
# <img src="Images/dict.png" width="700"/>

# %% [markdown]
# # dictionary
#
# unordered set of key, value pairs with the requirement that the keys are unique.
#
# * **unordered**:
# * **mutable**: key, value pair can be changed
# * **indexed**: unlike sequences, dictionaries are indexed **by keys** (any immutable type)
#     * **string** and **number** can always be keys
#     * **tuple** can be keys only if contains immutable type (directly or indirectly)
# * **dynamic**: key, value pairs can be added and removed

# %% [markdown]
# define an empty dictionary with curly braces `{}` or with built-in `dict` constructor

# %%
d = {}
d = dict()

# %% [markdown]
# create a dictionary by placing all pairs key/values, with the key separated from the values by a colon `:`, inside curly braces `{}` separated by comma

# %%
d = {'Athlete': 'Usain Bolt', 'Time': '9.58'}

# %%
d
# Out:
# {'Athlete': 'Usain Bolt', 'Time': '9.58'}

# %% [markdown]
# dictionary can be indexed by key listing the key inside squared bracket `[]`

# %%
print(d['Athlete'], " - ", d['Time'])
# Out:
# Usain Bolt  -  9.58

# %% [markdown]
# adding a pairs or changing its value is performed with item assignment

# %%
d['Nationality'] = 'Jamaica'
d
# Out:
# {'Athlete': 'Usain Bolt', 'Time': '9.58', 'Nationality': 'Jamaica'}

# %%
d.keys()
# Out:
# dict_keys(['Athlete', 'Time', 'Nationality'])

# %% [markdown]
# <div class="alert alert-info">
#
# * `Dict.keys()` return a set-like object providing a view on Dict's keys
#
# </div>

# %% [markdown]
# accessing a dictionary with a non existing key an exception of `KeyError` type is raised

# %%
d['Date']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 d['Date']
#
# KeyError: 'Date'

# %% [markdown]
# method `get` provide against raising exception for invalid keys

# %%
print(d.get('Date')) # return value of key if key is found otherwise return None value
# Out:
# None

# %%
print(d.get('Date', 'Unknown')) # if key is not found return 'Unknown'
# Out:
# Unknown

# %% [markdown]
# <div class="alert alert-info">
#
# * `Dict.get(k[,d])` Dict[k] if k in Dict, else d.  d defaults to None.
#
# </div>

# %% [markdown]
# ## dictionary looping

# %% [markdown]
# looping through keys

# %%
for k in d.keys():
    print(k, "=", d[k])
# Out:
# Athlete = Usain Bolt
# Time = 9.58

# %% [markdown]
# looping through values

# %%
d.values()
# Out:
# dict_values(['Usain Bolt', '9.58', 'Jamaica'])

# %% [markdown]
# <div class="alert alert-info">
#
# * `Dict.values()` return an object providing a view on Dict's values
#
# </div>

# %% [markdown]
# ## dictionary looping

# %% [markdown]
# looping through items

# %%
for k, v in d.items():
    print(k, "=", v)
# Out:
# Athlete = Usain Bolt
# Time = 9.58

# %% [markdown]
# <div class="alert alert-info">
#
# * `Dict.items()` a set-like object providing a view on D's items
#
# </div>

# %% [markdown]
# ### Men's 100 meters world record example
# 1. **read** file data
# 1. store data in a data container
#    * store data as **list** (one element for line) of **dictionaries** (one dictionary for world record)
#    * dictionary keys taken from table keys and dictionary values from columns
# 1. manage data to get **informations** about men's 100 meters world record

# %%
with open(file_data, 'r') as f:
    
    # read keys from 1st line and store them in a list
    keys = [i.strip() for i in f.readline().split("|")] 
    
    data = []                            # empty list for data
    for line in f:                       # loop over file lines
        values = line.split("|")         # store column values in a list (split line)
        record = {}                      # inizialize one record with empty dictionary
        for k, v in zip(keys, values):   # loop over both keys and values
            record[k] = v.strip()        # add column value to record dictionary
        data.append(record)              # append record to data list

# %% [markdown]
# <div class="alert alert-info">
#
# * `zip(iter1 [,iter2 [...]])` Return a zip object which returns a tuple where
#   the i-th element comes from the i-th element of each iterable passed as argument.
#   It continues until the shortest iterable is exhausted.
# </div>

# %% [markdown]
# ![image.png](attachment:8309b28d-b45f-408c-a99d-e452b7a03adf.png)

# %%
for (i, j, k) in zip(range(0, 3), range(1, 10), range(2, 20)):
    print(i, j, k)
# Out:
# 0 1 2
# 1 2 3
# 2 3 4

# %%
with open(file_data, 'r') as f:  
    keys = [i.strip() for i in f.readline().split("|")]
    data = []
    for line in f:
        values = line.split("|")

        record = {k: v.strip() for k, v in zip(keys, values)}
        
        data.append(record)

# %% [markdown]
# dictionary comprehension is a concise way to create a dictionary
#
# `{key: value for key, value in dictionary.items()}`

# %%
with open(file_data, 'r') as f:
    keys = [i.strip() for i in f.readline().split("|")]
    data = [ {k:v.strip() for k, v in zip(keys, line.split("|"))} for line in f]

# %%
for i in data:
    print(i['Time'], "-", i['Athlete'])
# Out:
# 10.06 - Bob Hayes
# 10.03 - Jim Hines
# 10.02 - Charles Greene
# 9.95 - Jim Hines
# 9.93 - Calvin Smith
# 9.83 - Ben Johnson
# 9.93 - Carl Lewis
# 9.93 - Carl Lewis
# 9.79 - Ben Johnson
# 9.92 - Carl Lewis
# 9.90 - Leroy Burrell
# 9.86 - Carl Lewis
# 9.85 - Leroy Burrell
# 9.84 - Donovan Bailey
# 9.79 - Maurice Greene
# 9.78 - Tim Montgomery
# 9.77 - Asafa Powell
# 9.77 - Justin Gatlin
# 9.77 - Asafa Powell
# 9.77 - Asafa Powell
# 9.74 - Asafa Powell
# 9.72 - Usain Bolt
# 9.69 - Usain Bolt
# 9.58 - Usain Bolt

# %%
print('number of records =', len(data))
# Out:
# number of records = 24

# %% [markdown]
# data is stored in descending order, last is the fastest.
# <br>
# Better to store in ascending order (fastest as first)

# %%
data.reverse()

# %% [markdown]
# <div class="alert alert-info">
#
# * `List.reverse()` reverse list order in place
#
# </div>

# %%
for i in data:
    print(i['Time'], "-", i['Athlete'])
# Out:
# 9.58 - Usain Bolt
# 9.69 - Usain Bolt
# 9.72 - Usain Bolt
# 9.74 - Asafa Powell
# 9.77 - Asafa Powell
# 9.77 - Asafa Powell
# 9.77 - Justin Gatlin
# 9.77 - Asafa Powell
# 9.78 - Tim Montgomery
# 9.79 - Maurice Greene
# 9.84 - Donovan Bailey
# 9.85 - Leroy Burrell
# 9.86 - Carl Lewis
# 9.90 - Leroy Burrell
# 9.92 - Carl Lewis
# 9.79 - Ben Johnson
# 9.93 - Carl Lewis
# 9.93 - Carl Lewis
# 9.83 - Ben Johnson
# 9.93 - Calvin Smith
# 9.95 - Jim Hines
# 10.02 - Charles Greene
# 10.03 - Jim Hines
# 10.06 - Bob Hayes

# %% [markdown]
# ### plot date vs time

# %% [markdown]
# get all world record times in a list

# %%
time = [float(i['Time']) for i in data]

# %% [markdown]
# dates are in format "Month Day, Year"

# %%
data[0]['Date']
# Out:
# 'August 16, 2009'

# %%
data[0]['Date'].split(',') # split date by comma
# Out:
# ['August 16', ' 2009']

# %%
data[0]['Date'].split(',')[1] # get year
# Out:
# ' 2009'

# %%
date = [ int(i['Date'].split(",")[1]) for i in data]

# %%
from datetime import datetime

#date = [datetime.strptime(i['Date'], '%B %d, %Y') for i in data]

# %%
import matplotlib.pyplot as plt

plt.scatter(date, time)
plt.xlabel("Date")
plt.ylabel("Time")
plt.show()

# %%
doped_athletes = ["Tyson Gay", "Yohan Blake", "Tim Montgomery", "Ben Johnson"]

# %%
for i, item in enumerate(data):
    if item['Athlete'] in doped_athletes:
        data.remove(item)

# %%
for i, item in enumerate(data):
    if item['Athlete'] in doped_athletes:
        del data[i]

# %%
for d in data:
    print(d['Time'], d['Athlete'])
    
print("number of records =", len(data))
# Out:
# 9.58 Usain Bolt
# 9.69 Usain Bolt
# 9.72 Usain Bolt
# 9.74 Asafa Powell
# 9.77 Asafa Powell
# 9.77 Asafa Powell
# 9.77 Justin Gatlin
# 9.77 Asafa Powell
# 9.79 Maurice Greene
# 9.84 Donovan Bailey
# 9.85 Leroy Burrell
# 9.86 Carl Lewis
# 9.90 Leroy Burrell
# 9.92 Carl Lewis
# 9.93 Carl Lewis
# 9.93 Carl Lewis
# 9.93 Calvin Smith
# 9.95 Jim Hines
# 10.02 Charles Greene
# 10.03 Jim Hines
# 10.06 Bob Hayes
# number of records = 21

# %%
time = [float(i['Time']) for i in data]
date = [ int(i['Date'].split(",")[1]) for i in data]

plt.scatter(date, time)
plt.xlabel("Date")
plt.ylabel("Time")
plt.show()

# %% [markdown]
# ### A new 100 meters world record!!!

# %%
d = dict.fromkeys(keys)

d
# Out:
# {'Time': None,
#  'Wind': None,
#  'Auto': None,
#  'Athlete': None,
#  'Nationality': None,
#  'Location of race': None,
#  'Date': None}

# %% [markdown]
# <div class="alert alert-info">
#
# * `Dict.fromkeys(iterable [, value])` Returns a new dict with keys from iterable and values equal to value.
#    value is optional, If not provided default value is None.
#
# </div>

# %%
# new world record

d['Athlete'] = 'Clark Kent'
d['Time'] = '9.42'
d['Nationality'] = 'Krypton'

d
# Out:
# {'Time': '9.42',
#  'Wind': None,
#  'Auto': None,
#  'Athlete': 'Clark Kent',
#  'Nationality': 'Krypton',
#  'Location of race': None,
#  'Date': None}

# %%
data.insert(0, d)

for d in data:
    print(d['Time'], "-", d['Athlete'])
# Out:
# 9.42 - Clark Kent
# 9.58 - Usain Bolt
# 9.69 - Usain Bolt
# 9.72 - Usain Bolt
# 9.74 - Asafa Powell
# 9.77 - Asafa Powell
# 9.77 - Asafa Powell
# 9.77 - Justin Gatlin
# 9.77 - Asafa Powell
# 9.79 - Maurice Greene
# 9.84 - Donovan Bailey
# 9.85 - Leroy Burrell
# 9.86 - Carl Lewis
# 9.90 - Leroy Burrell
# 9.92 - Carl Lewis
# 9.93 - Carl Lewis
# 9.93 - Carl Lewis
# 9.93 - Calvin Smith
# 9.95 - Jim Hines
# 10.02 - Charles Greene
# 10.03 - Jim Hines
# 10.06 - Bob Hayes

# %% [markdown]
# # Function with arbitrary number of arguments

# %% [markdown]
# a **non-keyworded arbitrary number** of positional arguments can be passed to a function.
# The positional arguments are placed in a **tuple**

# %%
def f(*args):
    """function with variable number of arguments"""
    print("args :", args)
    print("type :", type(args))

# %%
f('a', 'b', 'c')
# Out:
# args : ('a', 'b', 'c')
# type : <class 'tuple'>

# %% [markdown]
# single-asterisk form `*` can be mixed with ordinary list of arguments of a function

# %%
def f(a, b, c, *args):
    """function with both fixed positional arguments and variable list of arguments"""
    print("formal :", a, b, c)
    print("args   :", args)

# %%
f('a', 'b', 'c')
# Out:
# formal : a b c
# args   : ()

# %%
f('a', 'b', 'c', 'd', 'e')
# Out:
# formal : a b c
# args   : ('d', 'e')

# %% [markdown]
# **unpacking** non-keyworded arguments from a tuple

# %%
t = ('a', 'b', 'c', 'd', 'e')

f(*t)
# Out:
# formal : a b c
# args   : ('d', 'e')

# %% [markdown]
# a **keyworded arbitrary number** of arguments can be passed to a function.
# <br>
# When the arbitrary number of arguments are passed **by name** they are stored in a **dictionary**

# %%
def f(**kwargs):
    """function with variable number of arguments passed by name"""
    print("kwargs :", kwargs)
    print("type   :", type(kwargs))

# %%
f(a='a', b='b', c='c')
# Out:
# kwargs : {'a': 'a', 'b': 'b', 'c': 'c'}
# type   : <class 'dict'>

# %% [markdown]
# double-asterisk form `**` can be mixed with ordinary list of arguments of a function

# %%
def f(a, b, c, **kwargs):
    """function with both fixed positional arguments
       and variable list of arguments passed by name"""
    print("formal :", a, b, c)
    print("kwargs :", kwargs)

# %%
f(a='a', b='b', c='c')
# Out:
# formal : a b c
# kwargs : {}

# %%
f(a='a', b='b', c='c', d='d', e='e')
# Out:
# formal : a b c
# kwargs : {'d': 'd', 'e': 'e'}

# %% [markdown]
# **unpacking** keyworded arguments from a dictionary

# %%
d = {'a': 'a', 'b': 'b', 'c': 'c', 'd': 'd', 'e': 'e'}

f(**d)
# Out:
# formal : a b c
# kwargs : {'d': 'd', 'e': 'e'}

# %% [markdown]
# mixing all together: **ordinary** arguments, **non-keyworded** and **keyworded** variable length arguments list

# %%
def f(a, b, c, *args, **kwargs):
    """function with formal arguments and
       arbitrary number of list arguments positional and passed by name"""
    print("formal :", a, b, c)
    print("args   :", args)
    print("kwargs :", kwargs)

# %%
f('a', 'b', 'c', 'd', 'e')
# Out:
# formal : a b c
# args   : ('d', 'e')
# kwargs : {}

# %%
f(a='a', b='b', c='c', d='d', e='e')
# Out:
# formal : a b c
# args   : ()
# kwargs : {'d': 'd', 'e': 'e'}

# %%
f('a', 'b', 'c', 'd', e='e')
# Out:
# formal : a b c
# args   : ('d',)
# kwargs : {'e': 'e'}

# %% [markdown]
# **NB-1**: using name **\*args** and **\*\*kwargs** is just a convention.
#
# **NB-2**: respect order (**formal, \*args, \*\*kwargs**)

# %%
with open(file_data, 'r') as f:
    keys = [i.strip() for i in f.readline().split("|")]
    data = [ {k:v.strip() for k, v in zip(keys, line.split("|"))} for line in f]
    
print("\n", keys, "\n", data)

print(type(data))

for v in data:
    print("=", v)
# Out:
#  ['Time', 'Wind', 'Auto', 'Athlete', 'Nationality', 'Location of race', 'Date']
#  [{'Time': '10.06', 'Wind': '1.3', 'Auto': '', 'Athlete': 'Bob Hayes', 'Nationality': 'United States', 'Location of race': 'Tokyo, Japan', 'Date': 'October 15, 1964'}, {'Time': '10.03', 'Wind': '0.8', 'Auto': '', 'Athlete': 'Jim Hines', 'Nationality': 'United States', 'Location of race': 'Sacramento, USA', 'Date': 'June 20, 1968'}, {'Time': '10.02', 'Wind': '2.0', 'Auto': '', 'Athlete': 'Charles Greene', 'Nationality': 'United States', 'Location of race': 'Mexico City, Mexico', 'Date': 'October 13, 1968'}, {'Time': '9.95', 'Wind': '0.3', 'Auto': '', 'Athlete': 'Jim Hines', 'Nationality': 'United States', 'Location of race': 'Mexico City, Mexico', 'Date': 'October 14, 1968'}, {'Time': '9.93', 'Wind': '1.4', 'Auto': '', 'Athlete': 'Calvin Smith', 'Nationality': 'United States', 'Location of race': 'Colorado Springs, USA', 'Date': 'July 3, 1983'}, {'Time': '9.83', 'Wind': '1.0', 'Auto': '', 'Athlete': 'Ben Johnson', 'Nationality': 'Canada', 'Location of race': 'Rome, Italy', 'Date': 'August 30, 1987'}, {'Time': '9.93', 'Wind': '1.1', 'Auto': '', 'Athlete': 'Carl Lewis', 'Nationality': 'United States', 'Location of race': 'Rome, Italy', 'Date': 'August 30, 1987'}, {'Time': '9.93', 'Wind': '1.1', 'Auto': '', 'Athlete': 'Carl Lewis', 'Nationality': 'United States', 'Location of race': 'Zürich, Switzerland', 'Date': 'August 17, 1988'}, {'Time': '9.79', 'Wind': '1.1', 'Auto': '', 'Athlete': 'Ben Johnson', 'Nationality': 'Canada', 'Location of race': 'Seoul, South Korea', 'Date': 'September 24, 1988'}, {'Time': '9.92', 'Wind': '1.1', 'Auto': '', 'Athlete': 'Carl Lewis', 'Nationality': 'United States', 'Location of race': 'Seoul, South Korea', 'Date': 'September 24, 1988'}, {'Time': '9.90', 'Wind': '1.9', 'Auto': '', 'Athlete': 'Leroy Burrell', 'Nationality': 'United States', 'Location of race': 'New York, USA', 'Date': 'June 14, 1991'}, {'Time': '9.86', 'Wind': '1.2', 'Auto': '', 'Athlete': 'Carl Lewis', 'Nationality': 'United States', 'Location of race': 'Tokyo, Japan', 'Date': 'August 25, 1991'}, {'Time': '9.85', 'Wind': '1.2', 'Auto': '', 'Athlete': 'Leroy Burrell', 'Nationality': 'United States', 'Location of race': 'Lausanne, Switzerland', 'Date': 'July 6, 1994'}, {'Time': '9.84', 'Wind': '0.7', 'Auto': '9.835', 'Athlete': 'Donovan Bailey', 'Nationality': 'Canada', 'Location of race': 'Atlanta, USA', 'Date': 'July 27, 1996'}, {'Time': '9.79', 'Wind': '0.1', 'Auto': '', 'Athlete': 'Maurice Greene', 'Nationality': 'United States', 'Location of race': 'Athens, Greece', 'Date': 'June 16, 1999'}, {'Time': '9.78', 'Wind': '2.0', 'Auto': '', 'Athlete': 'Tim Montgomery', 'Nationality': 'United States', 'Location of race': 'Paris, France', 'Date': 'September 14, 2002'}, {'Time': '9.77', 'Wind': '1.6', 'Auto': '9.768', 'Athlete': 'Asafa Powell', 'Nationality': 'Jamaica', 'Location of race': 'Athens, Greece', 'Date': 'June 14, 2005'}, {'Time': '9.77', 'Wind': '1.7', 'Auto': '9.766', 'Athlete': 'Justin Gatlin', 'Nationality': 'United States', 'Location of race': 'Doha, Qatar', 'Date': 'May 12, 2006'}, {'Time': '9.77', 'Wind': '1.5', 'Auto': '9.763', 'Athlete': 'Asafa Powell', 'Nationality': 'Jamaica', 'Location of race': 'Gateshead, England', 'Date': 'June 11, 2006'}, {'Time': '9.77', 'Wind': '1.0', 'Auto': '9.762', 'Athlete': 'Asafa Powell', 'Nationality': 'Jamaica', 'Location of race': 'Zürich, Switzerland', 'Date': 'August 18, 2006'}, {'Time': '9.74', 'Wind': '1.7', 'Auto': '9.735', 'Athlete': 'Asafa Powell', 'Nationality': 'Jamaica', 'Location of race': 'Rieti, Italy', 'Date': 'September 9, 2007'}, {'Time': '9.72', 'Wind': '1.7', 'Auto': '', 'Athlete': 'Usain Bolt', 'Nationality': 'Jamaica', 'Location of race': 'New York, USA', 'Date': 'May 31, 2008'}, {'Time': '9.69', 'Wind': '0.0', 'Auto': '9.683', 'Athlete': 'Usain Bolt', 'Nationality': 'Jamaica', 'Location of race': 'Beijing, China', 'Date': 'August 16, 2008'}, {'Time': '9.58', 'Wind': '0.9', 'Auto': '9.572', 'Athlete': 'Usain Bolt', 'Nationality': 'Jamaica', 'Location of race': 'Berl ...
# <class 'list'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[152], line 9
#       5 print("\n", keys, "\n", data)
#       7 print(type(data))
# ----> 9 for k, v in data:
#      10     print(k, "=", v)
#
# ValueError: too many values to unpack (expected 2)
